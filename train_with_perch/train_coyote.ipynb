# %%
import torch
import pandas as pd
from pathlib import Path
import numpy as np
import pandas as pd
import random 
from glob import glob
import sklearn

from tqdm.autonotebook import tqdm
from sklearn.metrics import average_precision_score, roc_auc_score
from pathlib import Path

#set up plotting
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize']=[15,5] #for large visuals
# %config InlineBackend.figure_format = 'retina'

# opensoundscape transfer learning tools
from opensoundscape.ml.shallow_classifier import MLPClassifier, quick_fit, fit_classifier_on_embeddings
import os
from pathlib import Path
from pydub import AudioSegment
# Out:
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/3533495058.py:10: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
torch.manual_seed(0)
random.seed(0)
np.random.seed(0)

# %% [markdown]
# Processing data for training set

# %%
import os
from pathlib import Path
import pandas as pd

# Define dataset path
dataset_path = Path("/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/")
train_path = dataset_path / "train_5sec"

# Initialize lists for storing file details
audio_files = []
labels = []
start_times = []
end_times = []

# Function to traverse directories and map file information to labels
def traverse_and_map(directory, label):
    if not directory.exists():
        print(f"Directory does not exist: {directory}")
        return
    for root, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".mp3"):
                # Prepend full dataset path to the file path
                audio_path = dataset_path / Path(root).relative_to(dataset_path) / file
                audio_files.append(str(audio_path))
                labels.append(label)
                start_times.append(0.0)  # Fixed start time
                end_times.append(5.0)   # Fixed end time

# Iterate over each train size folder
if train_path.exists():
    for train_size_dir in train_path.iterdir():
        if train_size_dir.is_dir():  # Ensure it's a directory
            # Process `pos` and `neg` subdirectories in each train_size directory
            pos_dir = train_size_dir / "pos"
            neg_dir = train_size_dir / "neg"
            traverse_and_map(pos_dir, 1)  # True for "pos" files
            traverse_and_map(neg_dir, 0) # False for "negative" files
else:
    print(f"Train path does not exist: {train_path}")

# Create a DataFrame
data = {
    "file": audio_files,
    "start_time": start_times,
    "end_time": end_times,
    "A": labels  # Store labels under column "A"
}
labels_train = pd.DataFrame(data)

# Set MultiIndex with 'file', 'start_time', and 'end_time'
labels_train.set_index(["file", "start_time", "end_time"], inplace=True)

# Rename the only column to "A"
labels_train.columns = ['A']

# Display the resulting DataFrame
print(labels_train.head())

# Save the DataFrame to a CSV file (optional)
output_path = dataset_path / "audio_metadata_simple.csv"
labels_train.to_csv(output_path)
print(f"DataFrame saved to {output_path}")
# Out:
#                                                                         A
# file                                               start_time end_time
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# DataFrame saved to /Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/audio_metadata_simple.csv

# %%
print(dataset_path)
# Out:
# /Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec

# %%
print(labels_train)
# Out:
#                                                                         A
# file                                               start_time end_time
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# ...                                                                    ..
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
#
# [1800 rows x 1 columns]

# %% [markdown]
# Prepare audio Data

# %%
labels_train.head(20)
# Out:
#                                                                         A
# file                                               start_time end_time
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1

# %% [markdown]
# Step 1: Train shallow classifier on Perch embeddings

# %%
labels_train.index
# Out:
# MultiIndex([('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_150/pos/t-11031961_309_9sec_2_a.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_150/pos/t-11031961_194_9sec_1_a.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_150/pos/t-11031961_156_9sec_2_a.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_150/pos/t-11031961_193_9sec_1_a.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_150/pos/t-11031961_310_9sec_3_a.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_150/pos/t-11031961_138_9sec_1_f.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_150/pos/t-11031961_132_9sec_2_a.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_150/pos/t-11031961_186_9sec_1_b.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_150/pos/t-11031961_179_9sec_1_b.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_150/pos/t-11031961_135_9sec_2_a.mp3', ...),
#             ...
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_125/neg/t-11031961_340_9sec_1_a.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_125/neg/t-11031961_262_9sec_1_a.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_125/neg/t-11031961_277_9sec_1_a.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_125/neg/t-11031961_288_9sec_1_a.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_125/neg/t-11031961_355_9sec_1_a.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_125/neg/t-11031961_300_9sec_1_a.mp3', ...),
#             ( '/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_125/neg/t-11031961_63_9sec_1_a.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_125/neg/t-11031961_270_9sec_1_a.mp3', ...),
#             ('/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_125/neg/t-11031961_352_9sec_1_a.mp3', ...),
#             ( '/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/train_5sec/train_size_125/neg/t-11031961_64_9sec_1_a.mp3', ...)],
#            names=['file', 'start_time', 'end_time'], length=1800)

# %% [markdown]
# Step 2: Generate embeddings on the training and validation data

# %%
model = torch.hub.load('kitzeslab/bioacoustics-model-zoo','rana_sierrae_cnn',trust_repo=True)
# Out:
# Using cache found in /Users/yifeitao/.cache/torch/hub/kitzeslab_bioacoustics-model-zoo_main

# %%
emb_train = model.embed(labels_train, return_dfs=False, batch_size=32, num_workers=0)
# Out:
#   0%|          | 0/57 [00:00<?, ?it/s]
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999729166666667 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.9996875 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999770833333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999333333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999583333333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999520833333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999979166666667 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.9995416666666666 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.9996875 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999333333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999583333333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.9994375 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999583333333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999583333333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.9995416666666666 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999375 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.9995416666666666 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999583333333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999583333333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999729166666667 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.9994375 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.9996875 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999416666666667 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999770833333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999583333333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.9995625 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999583333333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999583333333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999583333333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.9994375 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999583333333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999416666666667 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999395833333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999916666666667 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999854166666666 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.9996875 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.99975 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999666666666666 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999708333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999645833333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.9998125 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999916666666667 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999729166666667 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999479166666666 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999791666666667 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999583333333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999333333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999333333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999333333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999708333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999791666666667 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999895833333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.9998125 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.99975 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999583333333334 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.9995416666666666 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999604166666667 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# ...
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.999833333333333 sec instead of 5.0 sec
#   warnings.warn(error_msg)

# %%
csv_path = Path("/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/test_dataset_5sec.csv")
audio_file_path = Path("/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/test_dataset_5sec.wav")
output_folder = Path("/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips")
output_csv_dir = Path("/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/")
output_csv = output_csv_dir / "processed_test_dataset_5sec.csv"

# Ensure the output directories exist
output_folder.mkdir(parents=True, exist_ok=True)
output_csv_dir.mkdir(parents=True, exist_ok=True)

# Read the CSV file
df_csv = pd.read_csv(csv_path)

# Determine label based on conditions
df_csv["A"] = df_csv.apply(
    lambda row: 1 if row["label"] == 1 and row["Annotation"] == "COYOTE" else 0, axis=1
)

# Load the audio file
audio = AudioSegment.from_file(audio_file_path)

# Initialize lists for DataFrame creation
file_paths = []
start_times = []
end_times = []
labels = []

# Partition the audio file into 5-second clips based on CSV
for index, row in df_csv.iterrows():
    start_time = index * 5 * 1000  # in milliseconds
    end_time = start_time + 5 * 1000  # 5 seconds later

    # Extract clip
    clip = audio[start_time:end_time]

    # Save clip to the output folder
    filename = row["filename"]
    clip_path = output_folder / filename
    clip.export(clip_path, format="wav")

    # Add details to lists
    file_paths.append(str(clip_path))
    start_times.append(0.0)  
    end_times.append(5.0)  
    labels.append(row["A"])

# Create the DataFrame
df_processed = pd.DataFrame({
    "file": file_paths,
    "start_time": start_times,
    "end_time": end_times,
    "A": labels
})
df_processed.set_index(["file", "start_time", "end_time"], inplace=True)
df_processed.columns = ['A']
# Save the DataFrame to a CSV file
df_processed.to_csv(output_csv, index=False)

print(f"Processed dataset saved to {output_csv}")
print(f"Audio clips saved to {output_folder}")
print(df_processed.head())
# Out:
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:20: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/test_dataset_5sec.wav'>
#   audio = AudioSegment.from_file(audio_file_path)
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_327_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_8_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_81_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_212_9sec_1_c.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_159_9sec_1_b.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_175_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_145_9sec_2_c.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_378_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_198_9sec_1_c.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_136_9sec_2_b.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_168_9sec_1_b.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_172_9sec_2_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_286_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_217_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_259_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_205_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_237_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_357_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_217_9sec_1_d.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_156_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_299_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_99_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_134_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_309_9sec_3_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_105_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_204_9sec_1_b.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_135_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_86_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_310_9sec_2_b.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_392_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_7_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_210_9sec_1_b.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_298_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_171_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_250_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_183_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_236_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_398_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_125_9sec_1_c.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_217_9sec_1_c.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_197_9sec_1_c.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_313_9sec_2_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_145_9sec_2_b.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_350_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_206_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_152_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_29_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_126_9sec_2_b.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_342_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_160_9sec_1_b.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_199_9sec_2_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_178_9sec_2_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_185_9sec_3_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_175_9sec_1_b.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_191_9sec_2_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_83_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_210_9sec_1_c.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_289_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_176_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_98_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_281_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_120_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_6_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_132_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_173_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_361_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_163_9sec_1_b.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_384_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_224_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_370_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_254_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_177_9sec_1_c.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_282_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_165_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_150_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_380_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_264_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_185_9sec_2_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_85_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_21_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_233_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_222_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_154_9sec_2_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_134_9sec_2_b.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_174_9sec_2_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_326_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_320_9sec_2_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_159_9sec_2_b.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_143_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_391_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_93_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_80_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_23_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_72_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_216_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_257_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_58_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_192_9sec_2_d.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_129_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1695598799.py:39: ResourceWarning: unclosed file <_io.BufferedRandom name='/Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips/t-11031961_109_9sec_1_a.wav'>
#   clip.export(clip_path, format="wav")
# Processed dataset saved to /Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/processed_test_dataset_5sec.csv
# Audio clips saved to /Users/yifeitao/Desktop/SoundHub/train_with_perch/coyotes_5sec/test_5sec/clips
#                                                                         A
# file                                               start_time end_time
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1

# %%
df_processed.head(20)
# Out:
#                                                                         A
# file                                               start_time end_time
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       0
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1
# /Users/yifeitao/Desktop/SoundHub/train_with_per... 0.0        5.0       1

# %%
labels_val = df_processed

# %%
emb_val = model.embed(labels_val, return_dfs=False, batch_size=32, num_workers=0)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/audio.py:1725: UserWarning: Audio object is shorter than requested duration: 4.987 sec instead of 5.0 sec
#   warnings.warn(error_msg)

# %% [markdown]
# Step 3: train the classification head on the desired classes

# %%
import torch.nn as nn

if isinstance(model.network, nn.Sequential):
    first_layer = model.network[0]
    if isinstance(first_layer, nn.Conv2d):
        model.network[0] = nn.Conv2d(
            in_channels=1,
            out_channels=first_layer.out_channels,
            kernel_size=first_layer.kernel_size,
            stride=first_layer.stride,
            padding=first_layer.padding
        )

# %%
emb_train.shape
# Out:
# torch.Size([1800, 3, 32, 16])

# %%
emb_val.shape
# Out:
# torch.Size([100, 3, 32, 16])

# %%
quick_fit(model.network, emb_train, labels_train.values, emb_val, labels_val.values, steps=1000)
# Out:
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/ml/shallow_classifier.py:110: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   train_features = torch.tensor(train_features, dtype=torch.float32, device=device)
# /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/ml/shallow_classifier.py:115: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   validation_features = torch.tensor(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 quick_fit(model.network, emb_train, labels_train.values, emb_val, labels_val.values, steps=1000)
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/opensoundscape/ml/shallow_classifier.py:126, in quick_fit(model, train_features, train_labels, validation_features, validation_labels, steps, optimizer, criterion, device)
#     123 model.train()
#     124 optimizer.zero_grad()
# --> 126 outputs = model(train_features)
#     127 loss = criterion(outputs, train_labels)
#     129 loss.backward()
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/torchvision/models/resnet.py:285, in ResNet.forward(self, x)
#     284 def forward(self, x: Tensor) -> Tensor:
# --> 285     return self._forward_impl(x)
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/torchvision/models/resnet.py:275, in ResNet._forward_impl(self, x)
#     273 x = self.layer1(x)
#     274 x = self.layer2(x)
# --> 275 x = self.layer3(x)
#     276 x = self.layer4(x)
#     278 x = self.avgpool(x)
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/torch/nn/modules/container.py:250, in Sequential.forward(self, input)
#     248 def forward(self, input):
#     249     for module in self:
# --> 250         input = module(input)
#     251     return input
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/torchvision/models/resnet.py:96, in BasicBlock.forward(self, x)
#      93 out = self.bn1(out)
#      94 out = self.relu(out)
# ---> 96 out = self.conv2(out)
#      97 out = self.bn2(out)
#      99 if self.downsample is not None:
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/torch/nn/modules/conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File /opt/anaconda3/envs/opensoundscape_env/lib/python3.9/site-packages/torch/nn/modules/conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)
#     547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:

# %% [markdown]
# Step 4: evaluate

# %%
# make predictions by passing the embeddings through the classifier
preds = model.network(torch.tensor(emb_val).float()).detach().numpy()

# plot histogram of scores for positive and negative clips
plt.hist(preds[labels_val==1],bins=20,alpha=0.5,label='positives')
plt.hist(preds[labels_val==0],bins=20,alpha=0.5,label='negatives')
plt.legend()

# calculate the area under the ROC score
roc_auc_score(labels_val.values,preds,average=None)
# Out:
# /var/folders/v4/chwhws6x79ncg51bwr5778b00000gn/T/ipykernel_4706/1204449858.py:2: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   preds = model.network(torch.tensor(emb_val).float()).detach().numpy()
# 0.9932
